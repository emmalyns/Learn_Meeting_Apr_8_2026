# %%
import numpy as np # this is called aliasing 
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# define functions together
def lin_fun_f(x):
    f = 5*x +1
    return f 

def pol_fun_g(x):
    g = 2*(x**2)+x-2
    return g

def sin_fun_h(x):
    h = np.sin(2*x) + 2*np.cos(3*x)
    return h

def taylor_approx(orderi, a, function):
    x = np.arange(0,10,1)
    j = 0
    while j < orderi:
        derivative = np.diff(function(x), j)
        j += 1 
        print(derivative)

# %%
x_center = 0.0
x_vals = np.linspace(x_center-1, x_center+1, 200)
y_vals = lin_fun_f(x_vals)

# %%
taylor_approx(2,1,pol_fun_g)
# Out:
# [ -2   1   8  19  34  53  76 103 134 169]
# [ 3  7 11 15 19 23 27 31 35]

# %%
x= 5
value = lin_fun_f(x)
print(value)
# Out:
# 26

# %%
x = np.arange(0,10,1)
# print(x)
lin_value = lin_fun_f(x)
pol_value = pol_fun_g(x)
# print(value)
print('x      y')
# for i in range(len(x)):
#     print(f'{x[i]}      {value[i]}')
# Out:
# x      y

# %%
fig, ax = plt.subplots()
ax.plot(x,pol_value,'o-')
ax.set_ylabel('value')
ax.set_xlabel('x')
plt.title('functions')
plt.show()
